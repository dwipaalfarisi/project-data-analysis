# %%
import pandas as pd
import numpy as np

# %%
# import dataset
dataset = pd.read_csv('./trends.csv')

# check the top 10
dataset.head(10)
# Out:
#    rank refresh_date        week country_code region_name region_code  term  \
# 0    23   2022-06-30  2017-07-02           ID        Aceh       ID-AC  Anna
# 1    23   2022-06-30  2017-07-09           ID        Aceh       ID-AC  Anna
# 2    23   2022-06-30  2017-07-23           ID        Aceh       ID-AC  Anna
# 3    23   2022-06-30  2017-09-10           ID        Aceh       ID-AC  Anna
# 4    23   2022-06-30  2017-09-24           ID        Aceh       ID-AC  Anna
# 5    23   2022-06-30  2017-11-19           ID        Aceh       ID-AC  Anna
# 6    23   2022-06-30  2018-01-21           ID        Aceh       ID-AC  Anna
# 7    23   2022-06-30  2018-03-11           ID        Aceh       ID-AC  Anna
# 8    23   2022-06-30  2018-05-20           ID        Aceh       ID-AC  Anna
# 9    23   2022-06-30  2018-05-27           ID        Aceh       ID-AC  Anna
#
#    score country_name
# 0    3.0    Indonesia
# 1    3.0    Indonesia
# 2    5.0    Indonesia
# 3    6.0    Indonesia
# ...

# %%
# Check the bottom 10
dataset.tail(10)
# Out:
#        rank refresh_date        week country_code      region_name  \
# 51957    22   2022-06-30  2019-07-14           ID  East Kalimantan
# 51958    22   2022-06-30  2019-07-28           ID  East Kalimantan
# 51959    22   2022-06-30  2019-08-25           ID  East Kalimantan
# 51960    22   2022-06-30  2019-09-01           ID  East Kalimantan
# 51961    22   2022-06-30  2019-09-08           ID  East Kalimantan
# 51962    22   2022-06-30  2019-09-15           ID  East Kalimantan
# 51963    22   2022-06-30  2019-11-03           ID  East Kalimantan
# 51964    22   2022-06-30  2019-12-15           ID  East Kalimantan
# 51965    22   2022-06-30  2019-12-22           ID  East Kalimantan
# 51966    22   2022-06-30  2019-12-29           ID  East Kalimantan
#
#       region_code               term  score country_name
# 51957       ID-KI  Sunny Tanuwidjaja    NaN    Indonesia
# 51958       ID-KI  Sunny Tanuwidjaja    NaN    Indonesia
# 51959       ID-KI  Sunny Tanuwidjaja    NaN    Indonesia
# ...

# %%
# Use dataframe
dataset_df = pd.DataFrame(dataset)
dataset_df
# Out:
#        rank refresh_date        week country_code      region_name  \
# 0        23   2022-06-30  2017-07-02           ID             Aceh
# 1        23   2022-06-30  2017-07-09           ID             Aceh
# 2        23   2022-06-30  2017-07-23           ID             Aceh
# 3        23   2022-06-30  2017-09-10           ID             Aceh
# 4        23   2022-06-30  2017-09-24           ID             Aceh
# ...     ...          ...         ...          ...              ...
# 51962    22   2022-06-30  2019-09-15           ID  East Kalimantan
# 51963    22   2022-06-30  2019-11-03           ID  East Kalimantan
# 51964    22   2022-06-30  2019-12-15           ID  East Kalimantan
# 51965    22   2022-06-30  2019-12-22           ID  East Kalimantan
# 51966    22   2022-06-30  2019-12-29           ID  East Kalimantan
#
#       region_code               term  score country_name
# 0           ID-AC               Anna    3.0    Indonesia
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51967 entries, 0 to 51966
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          51967 non-null  int64
#  1   refresh_date  51967 non-null  object
#  2   week          51967 non-null  object
#  3   country_code  51967 non-null  object
#  4   region_name   51967 non-null  object
#  5   region_code   51967 non-null  object
#  6   term          51967 non-null  object
#  7   score         6751 non-null   float64
#  8   country_name  51967 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.6+ MB

# %%
dataset_df.isna().any()
# Out:
# rank            False
# refresh_date    False
# week            False
# country_code    False
# region_name     False
# region_code     False
# term            False
# score            True
# country_name    False
# dtype: bool

# %%
# check null values for each columns
null_values = pd.isnull(dataset_df).sum()
null_values
# Out:
# rank                0
# refresh_date        0
# week                0
# country_code        0
# region_name         0
# region_code         0
# term                0
# score           45216
# country_name        0
# dtype: int64

# %%
# check the score column
# 51967 rows
# null + existing value = score
print(45216 + 6751)
# Out:
# 51967

# %%
# show the null values
dataset_missing = dataset_df.loc[dataset_df.isna().any(axis=1)]
dataset_missing
# Out:
#        rank refresh_date        week country_code              region_name  \
# 52       23   2022-06-30  2021-06-27           ID                     Aceh
# 134      23   2022-06-30  2017-08-20           ID  Bangka Belitung Islands
# 139      23   2022-06-30  2018-01-28           ID  Bangka Belitung Islands
# 143      23   2022-06-30  2018-06-17           ID  Bangka Belitung Islands
# 145      23   2022-06-30  2018-08-12           ID  Bangka Belitung Islands
# ...     ...          ...         ...          ...                      ...
# 51962    22   2022-06-30  2019-09-15           ID          East Kalimantan
# 51963    22   2022-06-30  2019-11-03           ID          East Kalimantan
# 51964    22   2022-06-30  2019-12-15           ID          East Kalimantan
# 51965    22   2022-06-30  2019-12-22           ID          East Kalimantan
# 51966    22   2022-06-30  2019-12-29           ID          East Kalimantan
#
#       region_code               term  score country_name
# ...

# %%
dataset_df['term'].dtype, dataset_df['score'].dtype
# Out:
# (dtype('O'), dtype('float64'))

# %%
# check the term and null value pair
dataset_df.loc[dataset_df['term'], ["score"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\PRO\data-analysis\data_analysis.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/PRO/data-analysis/data_analysis.ipynb#ch0000009?line=0'>1</a> # check the term and null value pair
# ----> <a href='vscode-notebook-cell:/d%3A/PRO/data-analysis/data_analysis.ipynb#ch0000009?line=1'>2</a> dataset_df.loc[dataset_df['term'], ["score"]]
#
# File d:\Code\JN\virtualenvir\data_analysis\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
type(dataset_df[["term", "score"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# Working with non null data
dataset_df[dataset_df["score"].notna()]
# Out:
#        rank refresh_date        week country_code  \
# 0        23   2022-06-30  2017-07-02           ID
# 1        23   2022-06-30  2017-07-09           ID
# 2        23   2022-06-30  2017-07-23           ID
# 3        23   2022-06-30  2017-09-10           ID
# 4        23   2022-06-30  2017-09-24           ID
# ...     ...          ...         ...          ...
# 51753    22   2022-06-30  2019-05-05           ID
# 51792    22   2022-06-30  2017-08-20           ID
# 51793    22   2022-06-30  2017-08-27           ID
# 51804    22   2022-06-30  2018-09-16           ID
# 51836    22   2022-06-30  2021-02-28           ID
#
#                              region_name region_code               term  \
# 0                                   Aceh       ID-AC               Anna
# 1                                   Aceh       ID-AC               Anna
# 2                                   Aceh       ID-AC               Anna
# ...

# %%
null_values1 = pd.isnull(dataset_df['score'])

for i in null_values1:
    if i == True:
        print(i)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
